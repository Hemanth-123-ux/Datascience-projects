# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanth-123-ux/Datascience-projects/blob/main/Hemanth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

path="/content/drive/MyDrive/energy.csv"
electricity=pd.read_csv(path)

print(electricity)



print(electricity.shape)
print(electricity.head(5))
print(electricity.tail(4))
print(electricity.info())
print(electricity.describe())
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# (100, 3)
#          Date        State  Consumption
# 0  01-01-2024    Tamilnadu       347.25
# 1  02-01-2024      Manipur       605.12
# 2  03-01-2024    Telengana       444.63
# 3  04-01-2024  Pondicherry       974.54
# 4  05-01-2024    Tamilnadu       864.02
#           Date        State  Consumption
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         100 non-null    object
#  1   State        100 non-null    object
#  2   Consumption  100 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB
# None
#        Consumption
# count   100.000000
# mean    534.090400
# std     245.341678
# min     100.470000
# 25%     321.570000
# 50%     517.075000
# 75%     726.215000
# max     997.970000

# %%
print("Column data")
print(electricity.columns)

print(electricity[electricity['State'].str.startswith('T')])
print(electricity[electricity['State'].str.endswith('A')])
rcb=electricity[electricity['State']=='Tripura']
print(len(rcb))
# Out:
# Column data
# Index(['Date', 'State', 'Consumption'], dtype='object')
#           Date      State  Consumption
# 0   01-01-2024  Tamilnadu       347.25
# 2   03-01-2024  Telengana       444.63
# 4   05-01-2024  Tamilnadu       864.02
# 5   06-01-2024    Tripura       749.56
# 6   07-01-2024  Telengana       312.39
# 7   08-01-2024  Telengana       330.46
# 9   10-01-2024    Tripura       739.60
# 23  24-01-2024    Tripura       725.31
# 27  28-01-2024    Tripura       194.94
# 28  29-01-2024  Tamilnadu       510.88
# 30  31-01-2024  Tamilnadu       474.86
# 38  08-02-2024  Tamilnadu       100.47
# 40  10-02-2024    Tripura       374.30
# 45  15-02-2024  Telengana       342.47
# 47  17-02-2024  Telengana       251.46
# 73  14-03-2024  Tamilnadu       523.27
# 78  19-03-2024  Telengana       235.65
# 79  20-03-2024    Tripura       557.38
# 87  28-03-2024  Tamilnadu       186.56
# 89  30-03-2024  Tamilnadu       457.81
# Empty DataFrame
# Columns: [Date, State, Consumption]
# Index: []
# 6

# %%
print(electricity.sort_values(by='State'))
print(np.max(electricity['Consumption']))
print(np.min(electricity['Consumption']))
print(np.mean(electricity['Consumption']))
# Out:
#           Date        State  Consumption
# 97  07-04-2024       Andhra       305.70
# 42  12-02-2024       Andhra       580.68
# 10  11-01-2024       Andhra       199.80
# 25  26-01-2024       Andhra       661.92
# 83  24-03-2024       Andhra       298.22
# ..         ...          ...          ...
# 85  26-03-2024           UP       828.55
# 26  27-01-2024           UP       366.07
# 96  06-04-2024           UP       726.21
# 13  14-01-2024  Uttarakhand       906.19
# 50  20-02-2024  Uttarakhand       463.45
#
# [100 rows x 3 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-705f21948ab1> in <cell line: 2>()
#       1 print(electricity.sort_values(by='State'))
# ----> 2 print(np.max(electricity['Consumption']))
#       3 print(np.min(electricity['Consumption']))
#       4 print(np.mean(electricity['Consumption']))
#
# NameError: name 'np' is not defined

# %%
#state1_data=electricity[electricity['State']==Andhra]
state1_data=electricity[electricity.State=='Andhra']
print("Andhra Data")
print(state1_data)
state2_data=electricity[electricity['State']=='Karnataka']
state4_data=electricity[electricity['State']=='Telegana']
state5_data=electricity[electricity['State']=='Tripura']

fig, axes= plt.subplots(2)
axes[0].plot(state1_data['Date'],state1_data['Consumption'],marker='*',color='red')
axes[1].plot(state2_data['Date'],state1_data['Consumption'],marker='^',color='red')
# Out:
# Andhra Data
#           Date   State  Consumption
# 10  11-01-2024  Andhra       199.80
# 25  26-01-2024  Andhra       661.92
# 42  12-02-2024  Andhra       580.68
# 82  23-03-2024  Andhra       393.36
# 83  24-03-2024  Andhra       298.22
# 97  07-04-2024  Andhra       305.70

# %%
state1_data=electricity[electricity.State=='Andhra']
fig, axes1= plt.subplots(2)
axes1[0].bar(state1_data['Date'],state1_data['Consumption'],marker='*',color='red')
axes1[1].bar(state2_data['Date'],state2_data['Consumption'],marker='^',color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-e4045401ba11> in <cell line: 3>()
#       1 state1_data=electricity[electricity.State=='Andhra']
#       2 fig, axes1= plt.subplots(2)
# ----> 3 axes1[0].bar(state1_data['Date'],state1_data['Consumption'],marker='*',color='red')
#       4 axes1[1].bar(state2_data['Date'],state2_data['Consumption'],marker='^',color='red')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2486                 hatch=htch,
#    2487                 )
# -> 2488             r._internal_update(kwargs)
#    2489             r.get_path()._interpolation_steps = 100
#    2490             if orientation == 'vertical':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1195                     func = getattr(self, f"set_{k}", None)
#    1196                     if not callable(func):
# -> 1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
#    1199                     ret.append(func(v))
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'marker'

# %%
labels=[state1,state2]
state1_total=electricity[electricity['State']==state1]['Consumption'].sum()
state2_total=electricity[electricity['State']==state2]['Consumption'].sum()
energy=[state1_total,state2_total]
axes2[0].pie(energy,labels=labels,autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1d1f865be8dc> in <cell line: 1>()
# ----> 1 labels=[state1,state2]
#       2 state1_total=electricity[electricity['State']==state1]['Consumption'].sum()
#       3 state2_total=electricity[electricity['State']==state2]['Consumption'].sum()
#       4 energy=[state1_total,state2_total]
#       5 axes2[0].pie(energy,labels=labels,autopct='%1.1f%%')
#
# NameError: name 'state1' is not defined

# %%
labels=[state3,state4]
state1_total=electricity[electricity['State']==state3]['Consumption'].sum()
state1_total=electricity[electricity['State']==State4]['Consumption'].sum()
energy=[state3_total , state4_total]
axes2[1].pie(energy,labels=labels,autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0df7e8a47ce3> in <cell line: 1>()
# ----> 1 labels=[State3,State4]
#       2 state1_total=electricity[electricity['State']==state3]['Consumption'].sum()
#       3 state1_total=electricity[electricity['State']==State4]['Consumption'].sum()
#       4 energy=[state3_total , state4_total]
#       5 axes2[1].pie(energy,labels=labels,autopct='%1.1f%%')
#
# NameError: name 'State3' is not defined
